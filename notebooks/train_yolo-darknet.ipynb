# %%
# YOLO object detector - https://github.com/alexcamargoweb/yolo-object-detection
# Detecção de objetos utilizando YOLO, Darknet, OpenCV
# Adaptado de Jonas Granatyr - https://iaexpert.academy
# Arquivo: train_yolo-darknet.ipynb
# Dataset: COCO
# Execução via Google Colab

# %%
# ACESSO AO DRIVE

# monta o Google Drive
from google.colab import drive, output
drive.mount('/content/drive')
output.clear()
# acessa o diretório do projeto
# %cd /content/drive/MyDrive/yolo-object-detection

# %%
# TESTANDO A DETECÇÃO DE OBJETOS COM A YOLO

# executa a yolo passando as configurações da rede, os pesos e a imagem
# !/content/drive/MyDrive/yolo-object-detection/darknet/darknet detect cfg/yolov4.cfg yolov4.weights data/person.jpg 

# a entrada foi um exemplo "person.jpg" e a saída será "predictions.jpg"
# !cp /content/drive/MyDrive/yolo-object-detection/darknet/predictions.jpg /content/drive/MyDrive/yolo-object-detection/outputs/predictions.jpg

# %%
# VISUALIZANDO O RESULTADO 

import cv2
import matplotlib.pyplot as plt

# carrega a imagem gerada pela rede
imagem = cv2.imread("/content/drive/MyDrive/yolo-object-detection/outputs/predictions.jpg")
fig = plt.gcf()
fig.set_size_inches(18, 10)
plt.axis('off')
plt.imshow(cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB))
plt.show() # exibe a imagem
