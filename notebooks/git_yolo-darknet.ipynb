# %%
# YOLO object detector - https://github.com/alexcamargoweb/yolo-object-detection
# Detecção de objetos utilizando YOLO, Darknet, OpenCV
# Adaptado de Jonas Granatyr - https://iaexpert.academy
# Arquivo: git_yolo-darknet.ipynb
# Execução via Google Colab

# %%
# monta o drive
from google.colab import drive, output
drive.mount('/content/drive')
# acessa o diretório do projeto (depois de clonado)
# %cd /content/drive/MyDrive/yolo-object-detection
# limpa as saídas
output.clear()

# %%
# configurações iniciais de SSH (executar uma única vez)
# substituir o meu e-mail e repositório pelos seus :)

'''
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/

# !ssh-keygen -t rsa -b 4096 -C "alexcamargoweb@gmail.com"

# !cat /root/.ssh/id_rsa.pub (copie o conteúdo)
# !cat /root/.ssh/id_rsa (copie o conteúdo)

# !ssh-keyscan github.com >> /root/.ssh/known_hosts
# !chmod 644 /root/.ssh/known_hosts
# !chmod 600 /root/.ssh/id_rsa
# !ssh -T git@github.com

# !git config --global user.email "alexcamargoweb@gmail.com"
# !git config --global user.name "alexcamargoweb"

# !git clone git@github.com:alexcamargoweb/yolo-object-detection.git

# %cd /content/drive/MyDrive/yolo-object-detection/
'''

# %%
# configurações SSH para futuros acessos

# chave cadastrada no seu perfil do GitHub
key = \
'''
-----BEGIN RSA PRIVATE KEY-----

-----END RSA PRIVATE KEY-----
'''
# !mkdir -p /root/.ssh
with open(r'/root/.ssh/id_rsa', 'w', encoding = 'utf8') as fh:
    fh.write(key)
# !chmod 600 /root/.ssh/id_rsa
# !chmod 644 /root/.ssh/known_hosts
# !ssh-keyscan github.com >> /root/.ssh/known_hosts
# !ssh -T git@github.com
# Out:
# chmod: cannot access '/root/.ssh/known_hosts': No such file or directory
# # github.com:22 SSH-2.0-babeld-43595b96
# # github.com:22 SSH-2.0-babeld-43595b96
# # github.com:22 SSH-2.0-babeld-43595b96
# ...
# Hi alexcamargoweb! You've successfully authenticated, but GitHub does not provide shell access.

# %%
# vai até o diretório do do projeto
# %cd /content/drive/MyDrive/yolo-object-detection/

# configurações locais (as vezes é necessário executá-las)
# !rm /content/drive/MyDrive/yolo-object-detection/.git/index.lock
# !git config --global user.email "alexcamargoweb@gmail.com"
# !git config --global user.name "alexcamargoweb"

# update, add, commit ou push/pull as mudanças
#!git stash
# !git add .
# !git commit -m ''
# !git push origin main
