# %%
# YOLO object detector - https://github.com/alexcamargoweb/yolo-object-detection
# Detecção de objetos utilizando YOLO, Darknet, OpenCV
# Adaptado de Jonas Granatyr - https://iaexpert.academy
# Arquivo: install_yolo-darknet.ipynb
# Dataset: COCO
# Execução via Google Colab

# %%
# ACESSO AO DRIVE

# monta o Google Drive
from google.colab import drive, output
drive.mount('/content/drive')
output.clear()
# acessa o diretório do projeto
# %cd /content/drive/MyDrive/yolo-object-detection

# %%
# DOWNLOAD E COMPILAÇÃO DO DARKNET (executar uma única vez)

# remove os arquivos antigos (caso a intenção seja re-instalar)
# %rm -R /content/drive/MyDrive/yolo-object-detection/darknet

# clona o framework de DL Darknet (escrito em C)
# !git clone https://github.com/AlexeyAB/darknet

# entra do diretório clonado
# %cd darknet

# compila os arquivos baixados
# !make

# DOWNLOAD DA YOLO (COCO DATASET)

# baixa os pesos de uma arquitetura yolo pré-treinada
# a yolo foi treinada com a base de dados COCO, possuindo 80 classes
# https://cocodataset.org
# !wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.weights

# exibe todas classes COCO
# !cat data/coco.names
